# %%
from ultralytics import YOLO

model = YOLO("/home/murat/Desktop/bitirme/models/yolov8_fruit_v13.pt")

model.train(
    data="/home/murat/Desktop/bitirme/datasets/final_rotten_fresh_yolo/data.yaml",
    epochs=50,            
    imgsz=640,            
    batch=16,             
    patience=10,          
    device=0,             
    project="/home/murat/Desktop/bitirme/runs", 
    name="final_rotten_fruit_model" 
)

print("runs/final_rotten_fruit_model")
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7797MiB)
# ...
